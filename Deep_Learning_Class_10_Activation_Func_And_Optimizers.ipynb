# %% [markdown]
# Loss Function:
#
# How wrong is the model?
#
# - Model predicts -> loss measures mistake
# - training tries to minimize the loss
# - no loss -> no learning
#
# you're shooting arrows at a target
#
# - loss: distance from bullseye
# - optimizer: how you walk towards the bullseye
#
# MEan squared Error MSE: (loss='mse')
#
# MSE is highly sensitive to outliers
#
# MAE: Mean absolute error (loss='mae')
#
# Used for noisy real-world data or when outliers exist
#
# Binary CE (loss='binary_crossentropy')
#
# used in:
# - spam detection
# - fraud detection
# - sentiment analysis
#
# crossentropy:
# - punishes confident wrong predictions Hard
# - encourages correct probability estimation
#
# categorical crossentropy (loss='categorical_crossentropy)
#
# used for:
# - labels are one-hot encoded
#
# sparse categorical crossentropy (loss='sparse_categorical_crossentropy')

# %% [markdown]
# Optimizers:
#
# Optimizer decides:
#
# - how big a step to take
# - in which direction
# - how fast to learn
# how stable training is
#
# loss = destination
# optimizer = navigation system
#
# Types of optimizers:
#
# SGD: Stochastic Gradient Descent
#
# CHaracteristics: Simple, slow, no memory
#
# Problem: Gets stuck, zig-zags
#
# SGD with momentum
#
# - uses past gradients
# - reduces zig-zag
# - moves faster in right direction
#
# RMSProp
#
# - adjusts learning rate per parameter
# - prevents exploding gradients
#
# Set for:
# - RNNs
# - NLP
#
# Adam: RMSProp + Momentum optimizer = Adam(learning_rate=0.001)
#
# - Fast
# - Stable
# - Handles sparse gradients
#
# Learning rate:
#
# Too high -> loss explodes
# too low -> no learning

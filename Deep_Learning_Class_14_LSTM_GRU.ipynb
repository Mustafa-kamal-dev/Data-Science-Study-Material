# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, Dense

# %%
vocab_size = 10000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
max_length = 200
X_train = pad_sequences(X_train, maxlen= max_length)
X_test = pad_sequences(X_test, maxlen=max_length)

# %%
model_lstm = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length),
    LSTM(128),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model_lstm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_lstm.fit(X_train, y_train, epochs=3, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 151s 472ms/step - accuracy: 0.7180 - loss: 0.5288 - val_accuracy: 0.8340 - val_loss: 0.4034
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 154s 492ms/step - accuracy: 0.8946 - loss: 0.2683 - val_accuracy: 0.8366 - val_loss: 0.3671
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 146s 466ms/step - accuracy: 0.9316 - loss: 0.1852 - val_accuracy: 0.8696 - val_loss: 0.3279

# %%
model_gru = Sequential([Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length),
                        GRU(128),
                        Dense(1,activation='sigmoid')])
model_gru.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
model_gru.fit(X_train, y_train, epochs=3, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/3
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 145s 451ms/step - accuracy: 0.6469 - loss: 0.6054 - val_accuracy: 0.8442 - val_loss: 0.3724
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 144s 459ms/step - accuracy: 0.8833 - loss: 0.2821 - val_accuracy: 0.8514 - val_loss: 0.3530
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 143s 458ms/step - accuracy: 0.9374 - loss: 0.1709 - val_accuracy: 0.8720 - val_loss: 0.3146

# %%
lstm_loss, lstm_acc = model_lstm.evaluate(X_test, y_test)
gru_loss, gru_acc = model_gru.evaluate(X_test, y_test)
print(lstm_acc, gru_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 76s 98ms/step - accuracy: 0.8614 - loss: 0.3462
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8646 - loss: 0.3312
# 0.8619199991226196 0.8659999966621399

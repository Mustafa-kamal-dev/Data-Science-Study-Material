# %%
from sklearn.datasets import make_blobs
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=50, centers=2, random_state=6)
model = SVC(kernel='linear', C=1)
model.fit(X,y)
# Out:
# SVC(C=1, kernel='linear')

# %%
print(X)
# Out:
# [[  6.45519089  -9.46356669]
#  [  8.49142837  -2.54974889]
#  [  6.87151089 -10.18071547]
#  [  9.49649411  -3.7902975 ]
#  [  7.67619643  -2.82620437]
#  [  6.3883927   -9.25691447]
#  [  9.24223825  -3.88003098]
#  [  5.95313618  -6.82945967]
#  [  6.86866543 -10.02289012]
#  [  7.52132141  -2.12266605]
#  [  7.29573215  -4.39392379]
#  [  6.85086785  -9.92422452]
#  [  4.29225906  -8.99220442]
#  [  8.21597398  -2.28672255]
#  [  7.9683312   -3.23125265]
#  [  8.68185687  -4.53683537]
#  [  6.77811308  -9.80940478]
#  [  7.93333064  -3.51553205]
#  [  7.73046665  -4.72901672]
#  [  7.37578372  -8.7241701 ]
#  [  6.95292352  -8.22624269]
#  [  8.07502382  -4.25949569]
#  [  7.39169472  -3.1266933 ]
#  [  6.59823581 -10.20150177]
#  [  7.27059007  -4.84225716]
#  [  8.71445065  -2.41730491]
#  [  5.73005848  -4.19481136]
#  [  9.42169269  -2.6476988 ]
#  [  6.26221548  -8.43925752]
#  [  7.89359985  -7.41655113]
#  [  8.98426675  -4.87449712]
#  [ 10.48848359  -2.75858164]
#  [  5.45644482  -8.99900075]
#  [  6.50072722  -3.82403586]
#  [  7.07705089  -2.4047943 ]
#  [  9.07568367  -4.21790533]
#  [  7.92736799  -9.7615272 ]
#  [  7.29885085  -9.90563956]
#  [  6.6008728   -8.07144707]
#  [  5.94709536  -9.05353781]
#  [  5.88397542  -8.37284513]
#  [  5.37042238  -2.44715237]
#  [  8.21201164  -1.54781358]
#  [  6.40500112  -7.50322463]
#  [  6.94752781  -9.75794397]
#  [  6.04907774  -8.76969991]
#  [  8.32932478  -8.47191434]
#  [  6.37734541 -10.61510727]
#  [  4.29810787  -8.41461865]
#  [  7.97164446  -3.38236058]]

# %%
X[:,1]
# Out:
# array([ -9.46356669,  -2.54974889, -10.18071547,  -3.7902975 ,
#         -2.82620437,  -9.25691447,  -3.88003098,  -6.82945967,
#        -10.02289012,  -2.12266605,  -4.39392379,  -9.92422452,
#         -8.99220442,  -2.28672255,  -3.23125265,  -4.53683537,
#         -9.80940478,  -3.51553205,  -4.72901672,  -8.7241701 ,
#         -8.22624269,  -4.25949569,  -3.1266933 , -10.20150177,
#         -4.84225716,  -2.41730491,  -4.19481136,  -2.6476988 ,
#         -8.43925752,  -7.41655113,  -4.87449712,  -2.75858164,
#         -8.99900075,  -3.82403586,  -2.4047943 ,  -4.21790533,
#         -9.7615272 ,  -9.90563956,  -8.07144707,  -9.05353781,
#         -8.37284513,  -2.44715237,  -1.54781358,  -7.50322463,
#         -9.75794397,  -8.76969991,  -8.47191434, -10.61510727,
#         -8.41461865,  -3.38236058])

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap='coolwarm')

w = model.coef_[0] #slope
print(w)
b = model.intercept_[0] # y-intercept
print(b)
x_line = [min(X[:,0]), max(X[:,0])]
y_line = [(-w[0]*x - b)/w[1] for x in x_line]
plt.plot(x_line, y_line, 'k-', label='Decision Boundary')
y_up = [(-w[0]*x - b + 1)/w[1] for x in x_line]
y_down = [(-w[0]*x - b - 1)/w[1] for x in x_line]
plt.plot(x_line, y_up,'k--',label='Margin +1')
plt.plot(x_line, y_down,'k--',label='Margin -1')
plt.scatter(model.support_vectors_[:,0], model.support_vectors_[:,1],
            s=120, facecolors='none', edgecolors='k')
plt.legend()
plt.show()
# Out:
# [-0.25395113 -0.83807751]
# -3.211559897362612

# %%
'''
After training the SVM gives you the equation of the line
w1x1 + w2x2 + b = 0
Decision Boundary w0x + w1y + b = 0 --> y = (-b -w0x)/w1
Margin lines
Upper margin w0x + w1y + b = +1 --> y = (-w0x -b +1)/w1
Lower margin w0x + w1y + b = -1 --> y = (-w0x -b -1)/w1
'''

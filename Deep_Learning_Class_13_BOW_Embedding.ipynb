# %%
# I love this movie
# I adore this film

#The sentences have same meaning but for BOW these sentences are not same

# BOW -> index
# TF-IDF -> sort words by their frequency

#WORD EMBEDDING

# king-man + woman = queen

# Embedding(input_dim=1000, output_dim=16, input_length=6)

# input_dim = vocabulary size / total unique words
# output_dim = size of word vector (16,32,100,300)
# bigger: more expressive, slower

# word index -> lookup table -> vector

# How Embedding tries to establish relevance between words:
# i love orange juice
# i love apple juice

# dog bites man vs man bites dog

# i am not happy vs i am happy

# RNN Recurrent neural network:

# Input word -> Hidden state -> output
#            -> Memory

# I watched this movie yesterday and after 3 hours I realized it was terrible
